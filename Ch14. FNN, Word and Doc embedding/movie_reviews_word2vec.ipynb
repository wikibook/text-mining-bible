# %%
from gensim.models import Word2Vec

# %%
with open('2016_filtered_review.txt', encoding='utf-8') as f:
    docs = [line.strip().split('\t\t') for line in f]
docs1 = [doc[1].strip().split() for doc in docs]

# %%
print(docs1[:3])
# Out:
# [['아니', '딴', '그렇', '비', '비탄', '총', '대체', '왜', '들', '온겨'], ['진심', '쓰레기', '영화', '만들', '무서', '알', '쫄아', '틀었', '이건', '뭐', '웃', '거리', '없는', '쓰레기', '영화', '임'], ['역대', '좀비', '영화', '가장', '최고다', '원작', '만화', '읽어', '보려', '영화', '보고', '결정', '하려', '감독', '간츠', '실사', '했', '사람', '거르려', '그냥', '봤', '정말', '흠잡', '없는', '최고', '좀비', '영화', '잔인', '거', '싫어하지', '참고', '볼', '만하', '로미', '인물', '왜', '그런', '모르']]

# %% [markdown]
# ### sg=1, negative=10 인 경우

# %%
model_sg_n10 = Word2Vec(docs1, window=3, min_count=3, vector_size=100, sg=1, negative=10)
# https://radimrehurek.com/gensim/models/word2vec.html

# %%
model_sg_n10.wv['이정재']
# Out:
# array([-0.01606061, -0.02621389, -0.25598055, -0.09808043, -0.03386123,
#         0.08268115,  0.06817225,  0.3083896 ,  0.76354414, -0.22606601,
#        -0.13115029, -0.16026922, -0.24245474,  0.23829454, -0.15434356,
#        -0.4083906 ,  0.33397132,  0.00231081, -0.27970165, -0.21266536,
#        -0.38947567,  0.22501482,  0.16025983,  0.35221177, -0.48659292,
#        -0.12054366,  0.35464182,  0.18637136, -0.32610223,  0.07972894,
#         0.28045803, -0.00130935,  0.04894   , -0.09524932, -0.27646905,
#        -0.65193963, -0.37414843, -0.2184552 , -0.22775853,  0.13867874,
#        -0.26955882,  0.23440996, -0.5005638 , -0.32079613, -0.40079865,
#         0.40521783, -0.36999646, -0.27332714, -0.3079859 , -0.5119116 ,
#        -0.24245371, -0.37569106, -0.14618784, -0.36770704,  0.00589788,
#        -0.06786431,  0.09749332, -0.03208518, -0.06608792,  0.07344636,
#        -0.6393068 ,  0.05303822,  0.24005497, -0.05405064, -0.8064425 ,
#         0.16516823,  0.22878864, -0.30636486,  0.60426396, -0.0783325 ,
#         0.18168874,  0.11061367, -0.11076956,  0.5952961 ,  0.5954256 ,
#        -0.1260729 , -0.04083805, -0.54741096, -0.7912085 , -0.43672624,
#        -0.27685812,  0.21594448, -0.10410362,  0.3276742 ,  0.17951643,
#        -0.3580954 , -0.0145579 , -0.4495358 ,  0.45070127,  0.50234675,
#         0.52281314,  0.12482793,  0.52221626,  0.14732789,  0.43638903,
#         0.49462533, -0.6806764 ,  0.0097566 ,  0.42712498,  0.16687128],
#       dtype=float32)

# %%
len(model_sg_n10.wv['이정재'])
# Out:
# 100

# %%
import numpy as np

# %%
print(np.dot(model_sg_n10.wv['이정재'], model_sg_n10.wv['이범수'])/(np.linalg.norm(model_sg_n10.wv['이정재'])*np.linalg.norm(model_sg_n10.wv['이범수'])))
# Out:
# 0.8317151

# %%
model_sg_n10.wv.similarity('이정재', '이범수')
# Out:
# 0.8317151

# %%
model_sg_n10.wv.most_similar('이정재',topn=50)
# Out:
# [('이범수', 0.8317151665687561),
#  ('송강호', 0.7936761379241943),
#  ('공유', 0.7929511070251465),
#  ('김범수', 0.7697046399116516),
#  ('김남길', 0.7551538348197937),
#  ('정우성', 0.7354149222373962),
#  ('이병헌', 0.7319382429122925),
#  ('조재현', 0.7254022359848022),
#  ('박해일', 0.7210745215415955),
#  ('김윤석', 0.715883195400238),
#  ('김명민', 0.711133599281311),
#  ('김성균', 0.7101824283599854),
#  ('이진욱', 0.7037534117698669),
#  ('이성민', 0.7022665143013),
#  ('정재형', 0.7005531191825867),
#  ('마동석', 0.6985158920288086),
#  ('곽도원', 0.6955844759941101),
#  ('주지훈', 0.6945734024047852),
#  ('리암', 0.6940481066703796),
#  ('최태준', 0.6919249296188354),
#  ('김성호', 0.6862715482711792),
#  ('이재훈', 0.6843243837356567),
#  ('슨', 0.6821752190589905),
#  ('윌스미스', 0.682035505771637),
#  ('오태경', 0.6817890405654907),
#  ('김희원', 0.6814147233963013),
#  ('컴버배치', 0.6813647150993347),
#  ('김성오', 0.6812418103218079),
#  ('김남일', 0.6806067824363708),
#  ('톰하디', 0.6804526448249817),
#  ('공효진', 0.6797864437103271),
#  ('조정석', 0.6789807677268982),
#  ('박철민', 0.6787780523300171),
#  ('수역', 0.6783020496368408),
#  ('엄지원', 0.6777298450469971),
#  ('오지호', 0.6774646639823914),
#  ('강예원', 0.6764786839485168),
#  ('조진웅', 0.6763750910758972),
#  ('김선아', 0.6755358576774597),
#  ('배성우', 0.6745612025260925),
#  ('임시완', 0.6744603514671326),
#  ('범수', 0.6727422475814819),
#  ('최민식', 0.672656238079071),
#  ('김윤식', 0.6726335883140564),
#  ('김영민', 0.6723201274871826),
#  ('이제훈', 0.6718704700469971),
#  ('윤제문', 0.6717858910560608),
#  ('송광호', 0.6700556874275208),
#  ('유해진', 0.6699438691139221),
#  ('정진영', 0.6679844260215759)]

# %%
model_sg_n10.wv.most_similar('재밌',topn=50)
# Out:
# [('재미있', 0.8937579393386841),
#  ('재밌네', 0.8224031329154968),
#  ('재밌었', 0.8162956833839417),
#  ('재밌어', 0.8098920583724976),
#  ('잼남', 0.807747483253479),
#  ('재밋음', 0.7930057048797607),
#  ('재밋어용', 0.7898834943771362),
#  ('재밌아', 0.7741311192512512),
#  ('재밋엇음', 0.7704954743385315),
#  ('잼슴', 0.7670013308525085),
#  ('재밋었음', 0.7665397524833679),
#  ('재밌슴', 0.7657376527786255),
#  ('재밋는듯', 0.7623327970504761),
#  ('존잼임', 0.7600002288818359),
#  ('재밋엇어용', 0.7579025626182556),
#  ('재밌드', 0.7565441131591797),
#  ('재밋었습니', 0.751817524433136),
#  ('재미있었', 0.7516990303993225),
#  ('재밋게봣습니', 0.7495699524879456),
#  ('재밋엇', 0.7469191551208496),
#  ('쟈밋', 0.7464757561683655),
#  ('재밋네', 0.7434331774711609),
#  ('꿀잼임', 0.7434306144714355),
#  ('재밋게봣', 0.7410485744476318),
#  ('재밋네용', 0.7406662106513977),
#  ('재밌엇습니', 0.739679753780365),
#  ('재밋었어', 0.7379496693611145),
#  ('잼난', 0.7364262938499451),
#  ('재밌더', 0.7363362312316895),
#  ('재밋엇어', 0.7357194423675537),
#  ('재밋습니', 0.7329486012458801),
#  ('재미있네', 0.7325117588043213),
#  ('재미있더', 0.7323538064956665),
#  ('재밋습니당', 0.7319355607032776),
#  ('번보', 0.7301505208015442),
#  ('재밋게봄', 0.7293193936347961),
#  ('엇', 0.7280319333076477),
#  ('재밋구', 0.7276819348335266),
#  ('재밋당', 0.72535640001297),
#  ('더재밋', 0.7251896262168884),
#  ('닺', 0.724844217300415),
#  ('재밋습', 0.7218464016914368),
#  ('재밌던', 0.7217839956283569),
#  ('졸잼임', 0.720038115978241),
#  ('재밋어', 0.7193095684051514),
#  ('재미있아', 0.7192568182945251),
#  ('재미있겠', 0.7177298069000244),
#  ('재밌다', 0.7170615196228027),
#  ('짱재밋음', 0.7149124145507812),
#  ('꾸르잼', 0.7141111493110657)]

# %% [markdown]
# ### sg=1, negative=5 인 경우

# %%
model_sg_n5 = Word2Vec(docs1, window=3, min_count=3, vector_size=100, sg=1, negative=5)

# %%
model_sg_n5.wv.most_similar('이정재',topn=50)
# Out:
# [('이범수', 0.8172003030776978),
#  ('공유', 0.7978862524032593),
#  ('송강호', 0.7973722815513611),
#  ('정우성', 0.7592041492462158),
#  ('김범수', 0.7444796562194824),
#  ('이성민', 0.7426853775978088),
#  ('이병헌', 0.7379883527755737),
#  ('조재현', 0.7368772029876709),
#  ('박해일', 0.7290856242179871),
#  ('곽도원', 0.7205297946929932),
#  ('김윤석', 0.7138299942016602),
#  ('김남길', 0.7134795188903809),
#  ('김명민', 0.7057063579559326),
#  ('리암', 0.704317569732666),
#  ('마동석', 0.703184187412262),
#  ('주지훈', 0.7013429999351501),
#  ('황정민', 0.6971973776817322),
#  ('하정우', 0.6903363466262817),
#  ('조진웅', 0.685148298740387),
#  ('리슨', 0.6843426823616028),
#  ('김희원', 0.6829640865325928),
#  ('이진욱', 0.6826876401901245),
#  ('슨', 0.6804318428039551),
#  ('한지민', 0.6777978539466858),
#  ('박철민', 0.6739984154701233),
#  ('유준상', 0.6738300323486328),
#  ('김성균', 0.6666698455810547),
#  ('차승원', 0.6660432815551758),
#  ('정재형', 0.6647465229034424),
#  ('엄지원', 0.6620208621025085),
#  ('송광호', 0.66154944896698),
#  ('니암', 0.6598137617111206),
#  ('정진영', 0.6595533490180969),
#  ('김선아', 0.6594428420066833),
#  ('견자단', 0.6594336032867432),
#  ('정준호', 0.6591668128967285),
#  ('오태경', 0.657396137714386),
#  ('범수', 0.6571804285049438),
#  ('이재훈', 0.6566430926322937),
#  ('배성우', 0.6556421518325806),
#  ('오종혁', 0.654041588306427),
#  ('김남일', 0.6537081003189087),
#  ('윌스미스', 0.6517304182052612),
#  ('요한', 0.6516727209091187),
#  ('조정석', 0.6509382128715515),
#  ('닐슨', 0.6505137085914612),
#  ('변', 0.6499208807945251),
#  ('정제', 0.6489165425300598),
#  ('톰하디', 0.6486628651618958),
#  ('윤제문', 0.6486176252365112)]

# %%
model_sg_n5.wv.most_similar('재밌',topn=50)
# Out:
# [('재미있', 0.9052667021751404),
#  ('재밌네', 0.8334540128707886),
#  ('잼남', 0.8283228874206543),
#  ('재밌었', 0.8097699284553528),
#  ('재밌어', 0.8071557283401489),
#  ('재밋엇음', 0.7908972501754761),
#  ('재밋음', 0.7891359925270081),
#  ('재밋었음', 0.7768431305885315),
#  ('존잼임', 0.7599521279335022),
#  ('재밌아', 0.7569942474365234),
#  ('잼슴', 0.7540542483329773),
#  ('재미있었', 0.7515528202056885),
#  ('재밋었습니', 0.7510846257209778),
#  ('재밋었어', 0.7466459274291992),
#  ('재밋엇어용', 0.745994508266449),
#  ('재미있더', 0.7451939582824707),
#  ('재밋어용', 0.7442628741264343),
#  ('재미있네', 0.7425634264945984),
#  ('쟈밋', 0.7425049543380737),
#  ('재밋어', 0.7419705390930176),
#  ('재밌슴', 0.7394275665283203),
#  ('엇', 0.7379399538040161),
#  ('재밋네', 0.7362236976623535),
#  ('재밌드', 0.7354043126106262),
#  ('재밋엇', 0.7324047684669495),
#  ('재밋구', 0.7322465181350708),
#  ('재밋게봣어', 0.731403648853302),
#  ('재밋습니', 0.7299796938896179),
#  ('존잼', 0.7290003895759583),
#  ('재밋게봣', 0.725676953792572),
#  ('꿀잼', 0.7253202795982361),
#  ('재밋었', 0.7241740226745605),
#  ('재밋었네', 0.7235016822814941),
#  ('재밋는듯', 0.719689130783081),
#  ('재밋습', 0.7177329063415527),
#  ('재밋엇어', 0.7157418727874756),
#  ('재밋게봣습니', 0.7151839733123779),
#  ('재밌던', 0.7151419520378113),
#  ('재밌더', 0.7147350311279297),
#  ('재미있겠', 0.7117310762405396),
#  ('개꿀잼', 0.710920512676239),
#  ('재밋네용', 0.7101173400878906),
#  ('꾸르잼', 0.707853376865387),
#  ('잼난', 0.7078503966331482),
#  ('재밋습니당', 0.7072466611862183),
#  ('꿀잼임', 0.7066858410835266),
#  ('재밌고', 0.7017881274223328),
#  ('재밋당', 0.7007712721824646),
#  ('재밋', 0.7007690072059631),
#  ('짱재밋어', 0.6992257833480835)]

# %% [markdown]
# ### sg=0, negative=10 인 경우

# %%
model_cbow_n10 = Word2Vec(docs1, window=3, min_count=3, vector_size=100, sg=0, negative=10)

# %%
model_cbow_n10.wv.most_similar('이정재',topn=50)
# Out:
# [('이범수', 0.7520221471786499),
#  ('김윤석', 0.7335158586502075),
#  ('공유', 0.7186737060546875),
#  ('조재현', 0.7176107168197632),
#  ('이성민', 0.7007914781570435),
#  ('이진욱', 0.6980976462364197),
#  ('송강호', 0.6973556280136108),
#  ('김범수', 0.6923631429672241),
#  ('주지훈', 0.6922031044960022),
#  ('박해일', 0.6827734708786011),
#  ('김남길', 0.670441210269928),
#  ('엄지원', 0.6626071929931641),
#  ('조진웅', 0.6606549620628357),
#  ('하정우', 0.6384184956550598),
#  ('송광호', 0.6380978226661682),
#  ('조정석', 0.6338980197906494),
#  ('이병헌', 0.632839560508728),
#  ('차승원', 0.6293016076087952),
#  ('민호', 0.6250593066215515),
#  ('공효진', 0.6237221956253052),
#  ('임시완', 0.6231607794761658),
#  ('김성오', 0.6223459839820862),
#  ('황정민', 0.621874988079071),
#  ('마동석', 0.6212318539619446),
#  ('정우성', 0.6205726861953735),
#  ('조니뎁', 0.6160702109336853),
#  ('윤제문', 0.6137752532958984),
#  ('남자배우', 0.6131156086921692),
#  ('김명민', 0.6131121516227722),
#  ('최태준', 0.6123997569084167),
#  ('박철민', 0.6119138598442078),
#  ('요한', 0.6056757569313049),
#  ('곽도원', 0.6046336889266968),
#  ('김영애', 0.6040281653404236),
#  ('류승범', 0.6030529141426086),
#  ('진세연', 0.6028896570205688),
#  ('김성균', 0.6011903882026672),
#  ('김고은', 0.5997008085250854),
#  ('임슬옹', 0.5993868112564087),
#  ('이희준', 0.5975204110145569),
#  ('강예원', 0.5963718295097351),
#  ('윌스미스', 0.5938354134559631),
#  ('톰하디', 0.5933815836906433),
#  ('이제훈', 0.5922765135765076),
#  ('김원해', 0.5921869874000549),
#  ('류준열', 0.5874252319335938),
#  ('배성우', 0.5846519470214844),
#  ('류덕환', 0.5781581997871399),
#  ('박희순', 0.57418292760849),
#  ('악역', 0.570225715637207)]

# %%
model_cbow_n10.wv.most_similar('재밌',topn=50)
# Out:
# [('재미있', 0.8959221839904785),
#  ('재밌네', 0.8125645518302917),
#  ('재밌어', 0.8115828037261963),
#  ('재밋음', 0.7938838005065918),
#  ('재밌었', 0.786245584487915),
#  ('재미있었', 0.7183651328086853),
#  ('재미있네', 0.7169124484062195),
#  ('재밌더', 0.7087268829345703),
#  ('재밌는', 0.7062791585922241),
#  ('재밋엇어', 0.7049375176429749),
#  ('재밋어', 0.6983798742294312),
#  ('잼남', 0.6980025768280029),
#  ('재밋엇', 0.681307852268219),
#  ('재밌던', 0.6752316951751709),
#  ('재밋', 0.6735064387321472),
#  ('재밋네', 0.6711117029190063),
#  ('재미있어', 0.6608949899673462),
#  ('재밋었', 0.6488674283027649),
#  ('재밌다', 0.6430715322494507),
#  ('재밋었어', 0.6288456916809082),
#  ('꿀잼', 0.6280269026756287),
#  ('재밌고', 0.6108897924423218),
#  ('재미있던', 0.608830451965332),
#  ('재미있는', 0.6070678234100342),
#  ('재밋엇음', 0.6069206595420837),
#  ('재밌게', 0.6030288338661194),
#  ('재미있다', 0.5952616930007935),
#  ('재밌구', 0.5859249234199524),
#  ('개꿀잼', 0.5715656280517578),
#  ('잼', 0.5706517696380615),
#  ('웃김', 0.5646745562553406),
#  ('재미있더', 0.5623772740364075),
#  ('재밋습니', 0.5613275170326233),
#  ('재밋었음', 0.5590972900390625),
#  ('재밌겠', 0.5563200116157532),
#  ('존잼', 0.5473002195358276),
#  ('재밌으', 0.5468595027923584),
#  ('재미있게', 0.5432825684547424),
#  ('괜찮', 0.53293776512146),
#  ('무서웠', 0.530391275882721),
#  ('재미있고', 0.5275177359580994),
#  ('웃겼', 0.5145192742347717),
#  ('만족스러웠', 0.5121500492095947),
#  ('재미나', 0.5103040933609009),
#  ('재미있구', 0.5061427354812622),
#  ('재미없', 0.5053384900093079),
#  ('재밋어용', 0.5029653310775757),
#  ('재미있겠', 0.48792821168899536),
#  ('잘만', 0.48768872022628784),
#  ('멋있', 0.48521581292152405)]

# %% [markdown]
# ### sg=0, negative=5 인 경우

# %%
model_cbow_n5 = Word2Vec(docs1, window=3, min_count=3, vector_size=100, sg=0, negative=5)

# %%
model_cbow_n5.wv.most_similar('재밌',topn=50)
# Out:
# [('재미있', 0.8944427967071533),
#  ('재밌어', 0.8198767900466919),
#  ('재밌네', 0.8074885010719299),
#  ('재밋음', 0.7908437848091125),
#  ('재밌었', 0.7884377241134644),
#  ('재밋어', 0.7461671233177185),
#  ('재밌는', 0.7392154335975647),
#  ('재미있었', 0.7220969200134277),
#  ('재미있네', 0.7164773344993591),
#  ('재밌더', 0.705155074596405),
#  ('잼남', 0.7017825245857239),
#  ('재밌던', 0.6955278515815735),
#  ('재밋네', 0.6856726408004761),
#  ('재밋엇어', 0.6818797588348389),
#  ('재미있어', 0.6814988255500793),
#  ('재밋', 0.6701798439025879),
#  ('재미있던', 0.6597896218299866),
#  ('재밌다', 0.6590223908424377),
#  ('재밋엇', 0.6520659327507019),
#  ('재밋었어', 0.6516850590705872),
#  ('꿀잼', 0.6516437530517578),
#  ('재밌고', 0.6467437744140625),
#  ('재밋었', 0.6399656534194946),
#  ('재미있는', 0.633817732334137),
#  ('재밋엇음', 0.633155345916748),
#  ('재밌게', 0.6214451193809509),
#  ('재미있다', 0.6070243716239929),
#  ('재밌구', 0.6018065214157104),
#  ('잼', 0.5908449292182922),
#  ('재밌으', 0.5786080360412598),
#  ('재미있고', 0.5705485343933105),
#  ('재밋습니', 0.5637672543525696),
#  ('개꿀잼', 0.5602684020996094),
#  ('웃김', 0.5590330362319946),
#  ('재미있게', 0.5576227307319641),
#  ('재미있더', 0.5532048940658569),
#  ('존잼', 0.5513148903846741),
#  ('재밋었음', 0.5497215390205383),
#  ('재밋었습니', 0.5428133010864258),
#  ('재미나', 0.5407035946846008),
#  ('재미없', 0.5361926555633545),
#  ('괜찮', 0.5289772748947144),
#  ('무서웠', 0.5205384492874146),
#  ('재밌겠', 0.5131988525390625),
#  ('재미있구', 0.5100371241569519),
#  ('재밋어용', 0.5043978095054626),
#  ('재미있겠', 0.5030668377876282),
#  ('무서', 0.5008906126022339),
#  ('핵꿀잼', 0.5006813406944275),
#  ('웃겼', 0.4957692623138428)]

# %% [markdown]
# ## Out of vocabulary 문제

# %%
model_sg_n10.wv['우주평화']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19072/3851185653.py in <module>
# ----> 1 model_sg_n10.wv['우주평화']
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in __getitem__(self, key_or_keys)
#     402         """
#     403         if isinstance(key_or_keys, _KEY_TYPES):
# --> 404             return self.get_vector(key_or_keys)
#     405
#     406         return vstack([self.get_vector(key) for key in key_or_keys])
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in get_vector(self, key, norm)
#     445
#     446         """
# --> 447         index = self.get_index(key)
#     448         if norm:
#     449             self.fill_norms()
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in get_index(self, key, default)
#     419             return default
#     420         else:
# --> 421             raise KeyError(f"Key '{key}' not present")
#     422
#     423     def get_vector(self, key, norm=False):
#
# KeyError: "Key '우주평화' not present"
