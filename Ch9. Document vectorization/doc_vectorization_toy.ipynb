# %% [markdown]
# ### 예제 텍스트 데이터

# %% [markdown]
# Doc 1: 'banana apple apple orange'<br>
# Doc 2: 'apple carrot eggplant carrot'<br>
# Doc 3: 'banana mango orange orange'<br>

# %% [markdown]
# 위 텍스트 데이터에 대한 DTM은 아래와 같습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
# 각 문서를 벡터로 표현하기
Doc1 = np.array([2,1,0,0,0,1])
Doc2 = np.array([1,0,2,1,0,0])
Doc3 = np.array([0,1,0,0,1,2])

# %%
# 문서 간 유클리디안 거리 구하기
print(np.linalg.norm(Doc2-Doc1))
print(np.linalg.norm(Doc3-Doc1))
# Out:
# 2.8284271247461903
# 2.449489742783178

# %%
# 문서들 간의 코사인 유사도
print(np.dot(Doc1, Doc2)/(np.linalg.norm(Doc1)*np.linalg.norm(Doc2)))
print(np.dot(Doc1, Doc3)/(np.linalg.norm(Doc1)*np.linalg.norm(Doc3)))
# Out:
# 0.33333333333333337
# 0.5000000000000001
