# %% [markdown]
# ### read() 사용해서 파일 내용 읽어오기

# %%
# example.txt 파일에 읽기 모드로 접근합니다.
f = open('example.txt', 'r')

# %%
# read() 함수를 이용해서 해당 파일의 내용을 읽어옵니다.
content = f.read()

# %%
# 파일을 읽어온 다음에는 close() 함수를 호출해서 파일을 종료합니다.
f.close()

# %%
content
# Out:
# '1\n2\n3\n4\n5\n'

# %% [markdown]
# ### readlines() 사용해서 파일 내용 읽어오기

# %%
f1 = open('example.txt', 'r')
content1 = f1.readlines() 
f1.close()

# %%
content1
# Out:
# ['1\n', '2\n', '3\n', '4\n', '5\n']

# %% [markdown]
# ### readline() 사용해서 파일 내용 읽어오기

# %%
f2 = open('example.txt', 'r')

# %%
f2.readline()
# Out:
# '1\n'

# %%
f2.readline()
# Out:
# '2\n'

# %%
f2.close()

# %% [markdown]
# ## 숫자로 되어 있는 텍스트 정보를 읽어와서 숫자 연산하기

# %% [markdown]
# 숫자가 아닌 문자를 포함하고 있는 문자열은 int()나 float() 함수를 이용해서 숫자로 변환할 수 없습니다. 아래의 경우, 변수 a가 갖는 문자열 데이터에 'b'라고 하는 숫자가 아닌 문자가 포함되어 있어, 이에 int() 함수를 적용하면 에러가 발생합니다.

# %%
a='3b'

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17952/766485689.py in <module>
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: '3b'

# %%
for num in content1:
    num = num.strip()
    num = int(num)
    new_num = num + 1
    print(new_num)
# Out:
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# ## 파일에 내용 쓰기 (write)

# %%
# 파일에 쓰기 모드로 접근합니다.
f = open('results.txt','w')

# %%
# write() 함수의 인자는 문자열이어야 합니다.
f.write(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17952/657472581.py in <module>
#       1 # write() 함수의 인자는 문자열이어야 합니다.
# ----> 2 f.write(100)
#
# TypeError: write() argument must be str, not int

# %%
f.write('Today is a good day.')
# Out:
# 20

# %%
f.write('Tomorrow will be another day.')
# Out:
# 29

# %%
f.close()

# %%
f = open('results.txt','w')
f.write('Today is a good day.\n')
f.write('Tomorrow will be another day.')
f.close()

# %% [markdown]
# ### append 모드 사용하기

# %%
f_a = open('append_example.txt', 'a')
f_a.write('4\n')
f_a.write('5\n')
f_a.close()

# %% [markdown]
# ### 구분자를 이용해서 저장하기

# %%
age_2000 = [22, 33, 31, 42, 12, 26, 19, 56, 54, 40]

# %%
f = open('ages.txt', 'w')
for age in age_2000:
    age_2020 = age + 20
    f.write(str(age)+'\t'+str(age_2020)+'\n')
f.close()

# %% [markdown]
# ## 한글 읽기

# %%
f_kr = open('korean_test.txt','r', encoding='utf8')
content = f_kr.read()
f_kr.close()

# %%
content
# Out:
# '오늘은 좋은 날입니다.'

# %% [markdown]
# ## 한글 쓰기

# %%
f_kr1 = open('korean_test_w.txt','w', encoding='utf8')
f_kr1.write('내일은 토요일 입니다.')
f_kr1.close()

# %% [markdown]
# ## with ... as 구문 사용하기

# %%
with open('example.txt', 'r') as f:
    content = f.read()

# %%
content
# Out:
# '1\n2\n3\n4\n5\n'

# %% [markdown]
# ## 대용량 파일 읽어오기

# %%
with open('example.txt', 'r') as f:
    for line in f:
        print(line)
# Out:
# 1
#
# 2
#
# 3
#
# 4
#
# 5
