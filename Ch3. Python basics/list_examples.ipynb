# %% [markdown]
# ### 리스트 데이터

# %%
# 원소가 세 개인 리스트 데이터의 예
['python', 1, 5]
# Out:
# ['python', 1, 5]

# %%
a=['python', 1, 5]

# %%
type(a)
# Out:
# list

# %% [markdown]
# ### Indexing

# %%
a[0]
# Out:
# 'python'

# %%
a[2]
# Out:
# 5

# %% [markdown]
# 음의 인덱스 사용

# %%
a[-1] # a의 마지막 원소에 접급합니다.
# Out:
# 5

# %% [markdown]
# ### Slicing

# %%
a[1:3]
# Out:
# [1, 5]

# %% [markdown]
# slicing 결과를 새로운 변수에 저장하기

# %%
a1 = a[1:3]
a1
# Out:
# [1, 5]

# %% [markdown]
# ### 기존 원소의 값 변경하기

# %%
a[1]=10

# %%
a
# Out:
# ['python', 10, 5]

# %%
a[0:2] = ['java', -1]

# %%
a
# Out:
# ['java', -1, 5]

# %% [markdown]
# ### 리스트 methods 목록 보기

# %%
print(dir(a))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
help(a.append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.

# %%
# ?a.append

# %%
a
# Out:
# ['java', -1, 5]

# %% [markdown]
# ### append()
# append() 는 하나의 새로운 원소를 리스트 변수의 끝에 추가하고 하는 경우 사용

# %%
a.append('python')

# %%
a
# Out:
# ['java', -1, 5, 'python']

# %% [markdown]
# ### count()

# %%
d = [1,2,2,3,3,4,5,5]

# %%
d.count(5)
# Out:
# 2

# %% [markdown]
# ### extend()

# %%
f=['data', 'text']

# %%
d.extend(f)

# %%
d
# Out:
# [1, 2, 2, 3, 3, 4, 5, 5, 'data', 'text']

# %% [markdown]
# ### insert()

# %%
d.insert(1, 'computer')

# %%
d
# Out:
# [1, 'computer', 2, 2, 3, 3, 4, 5, 5, 'data', 'text']

# %%
d.remove(5)

# %%
d
# Out:
# [1, 'computer', 2, 2, 3, 3, 4, 5, 'data', 'text']

# %% [markdown]
# ### sort()

# %%
d.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21524/575454195.py in <module>
# ----> 1 d.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
e=[3,2,4,1]

# %%
e.sort()

# %%
e
# Out:
# [1, 2, 3, 4]

# %%
e.sort(reverse=True)

# %%
e
# Out:
# [4, 3, 2, 1]

# %% [markdown]
# ## 일반 함수 (common function) 사용하기

# %% [markdown]
# ### len()

# %%
len(e)
# Out:
# 4

# %% [markdown]
# ### min()과 max()

# %%
g=[1,2,3,4,5]

# %%
min(g)
# Out:
# 1

# %%
max(g)
# Out:
# 5

# %%
s=['apple', 'air', 'banana', 'carrot']

# %%
min(s)
# Out:
# 'air'

# %%
max(s)
# Out:
# 'carrot'

# %%
# 서로 다른 데이터 타입 간에는 대소를 비교할 수 없습니다.
min([1,'a', 3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21524/1786484509.py in <module>
#       1 # 서로 다른 데이터 타입 간에는 대소를 비교할 수 없습니다.
# ----> 2 min([1,'a', 3])
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### sorted()

# %%
h=[3,1,2,4]

# %%
sorted(h)
# Out:
# [1, 2, 3, 4]

# %%
sorted(h, reverse=True)
# Out:
# [4, 3, 2, 1]

# %%
h
# Out:
# [3, 1, 2, 4]

# %% [markdown]
# ### in 연산자

# %%
3 in g
# Out:
# True

# %% [markdown]
# ### del

# %%
k=[1,2,3,4]

# %%
del k[0]

# %%
k
# Out:
# [2, 3, 4]

# %%
del k[0:2]

# %%
k
# Out:
# [4]
